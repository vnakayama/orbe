# %%
qtd=7 #poe os objetos que vc tem além da estrela. 
#No caso, eu tenho 3 objetos, por exemplo, 3 planetas além da estrela.

#quando rodar essa celula, você vai ter um arquivo .txt para cada um dos seus objetos.
#nesses arquivos txt, a primeira coluna é o tempo, depois vem a,e,i,w,nodo
#na celula seguinte a esta, eu abro o arquivo do planeta que eu quero e ploto os dados.


####Rode essa celula sem editar o que está aqui embaixo ################
#para rodar a celula é só clicar em algum lugar aqui do texto e fazer "shift+enter"
file=open('trappist/trappist_out.dat','r')
data=file.readlines()
file.close()

def separa_objetos(data, num):
    t,a,e,inc,w,nodo=[],[],[],[],[],[]
    for i in range(0, len(data)):
        obj_tempo=float(data[i].split()[0])
        obj_numero=float(data[i].split()[1])
        obj_a=float(data[i].split()[2])
        obj_e=float(data[i].split()[3])
        obj_i=float(data[i].split()[4])
        obj_w=float(data[i].split()[5])
        obj_nodo=float(data[i].split()[6])
        if obj_numero==num:
            t.append(obj_tempo)
            a.append(obj_a)
            e.append(obj_e)
            inc.append(obj_i)
            w.append(obj_w)
            nodo.append(obj_nodo)
    return [t, a, e, inc, w, nodo]

num=[]
for i in range(0,qtd):
    num.append(i+1)

obj=[]
for i in num:
    obj.append(separa_objetos(data,i)) 

for i in num:
    lista=obj[i-1]
    t=lista[0]
    a=lista[1]
    e=lista[2]
    inc=lista[3]
    w=lista[4]
    nodo=lista[5]
    datafile = open("trappist/data/trappist_"+str(i)+".txt", 'w')
    for j in range(0,len(t)):
        datafile.write(str(t[j])+" "+str(a[j]) + " " + str(e[j]) + " " + str(inc[j]) + " " +str(w[j])+" "+str(nodo[j])+"\n")
    datafile.close()

# %%
#agora rode esta celula
import matplotlib.pyplot as plt

# trappist = ['b','c','d','e','f','g','h']
# for l in range(7):
#     #plotando dados para o objeto 1
file1=open('trappist/data/trappist_1.txt','r')               #se voce quer ver os dados do planeta 2, coloque _2 ao inves de _1
data=file1.readlines()
file1.close()
t1,a1,e1,i1,w1,nodo1=[],[],[],[],[],[]
for ii in range(0,len(data)):
    t1.append(float(data[ii].split()[0]))
    a1.append(float(data[ii].split()[1]))
    e1.append(float(data[ii].split()[2]))
    i1.append(float(data[ii].split()[3]))
    w1.append(float(data[ii].split()[4]))
    nodo1.append(float(data[ii].split()[5]))

file2=open('trappist/data/trappist_2.txt','r')                  #se voce quer ver os dados do planeta 2, coloque _2 ao inves de _1
data=file2.readlines()
file2.close()
t2,a2,e2,i2,w2,nodo2=[],[],[],[],[],[]
for j in range(0,len(data)):
    t2.append(float(data[j].split()[0]))
    a2.append(float(data[j].split()[1]))
    e2.append(float(data[j].split()[2]))
    i2.append(float(data[j].split()[3]))
    w2.append(float(data[j].split()[4]))
    nodo2.append(float(data[j].split()[5]))

file3=open('trappist/data/trappist_3.txt','r')                  #se voce quer ver os dados do planeta 3, coloque _3 ao inves de _1
data=file3.readlines()
file3.close()
t3,a3,e3,i3,w3,nodo3=[],[],[],[],[],[]
for j in range(0,len(data)):
    t3.append(float(data[j].split()[0]))
    a3.append(float(data[j].split()[1]))
    e3.append(float(data[j].split()[2]))
    i3.append(float(data[j].split()[3]))
    w3.append(float(data[j].split()[4]))
    nodo3.append(float(data[j].split()[5]))

file4=open('trappist/data/trappist_4.txt','r')                  #se voce quer ver os dados do planeta 4, coloque _4 ao inves de _1
data=file4.readlines()
file4.close()
t4,a4,e4,i4,w4,nodo4=[],[],[],[],[],[]
for j in range(0,len(data)):
    t4.append(float(data[j].split()[0]))
    a4.append(float(data[j].split()[1]))
    e4.append(float(data[j].split()[2]))
    i4.append(float(data[j].split()[3]))
    w4.append(float(data[j].split()[4]))
    nodo4.append(float(data[j].split()[5]))

file5=open('trappist/data/trappist_5.txt','r')                  #se voce quer ver os dados do planeta 5, coloque _5 ao inves de _1
data=file5.readlines()
file5.close()
t5,a5,e5,i5,w5,nodo5=[],[],[],[],[],[]
for j in range(0,len(data)):
    t5.append(float(data[j].split()[0]))
    a5.append(float(data[j].split()[1]))
    e5.append(float(data[j].split()[2]))
    i5.append(float(data[j].split()[3]))
    w5.append(float(data[j].split()[4]))
    nodo5.append(float(data[j].split()[5]))

file6=open('trappist/data/trappist_6.txt','r')                  #se voce quer ver os dados do planeta 6, coloque _6 ao inves de _1
data=file6.readlines()
file6.close()
t6,a6,e6,i6,w6,nodo6=[],[],[],[],[],[]
for j in range(0,len(data)):
    t6.append(float(data[j].split()[0]))
    a6.append(float(data[j].split()[1]))
    e6.append(float(data[j].split()[2]))
    i6.append(float(data[j].split()[3]))
    w6.append(float(data[j].split()[4]))
    nodo6.append(float(data[j].split()[5]))

file7=open('trappist/data/trappist_7.txt','r')                  #se voce quer ver os dados do planeta 7, coloque _7 ao inves de _1
data=file7.readlines()
file7.close()
t7,a7,e7,i7,w7,nodo7=[],[],[],[],[],[]
for j in range(0,len(data)):
    t7.append(float(data[j].split()[0]))
    a7.append(float(data[j].split()[1]))
    e7.append(float(data[j].split()[2]))
    i7.append(float(data[j].split()[3]))
    w7.append(float(data[j].split()[4]))
    nodo7.append(float(data[j].split()[5]))


# fig, (ax1) = plt.subplots(1,1,sharex=True)
# fig.set_size_inches(10, 17.5)
# fig.suptitle('Mercúrio')

plt.plot(t1,e1,marker='o', linestyle='')
plt.plot(t2,e2,marker='o', linestyle='')
plt.plot(t3,e3,marker='o', linestyle='')
plt.plot(t4,e4,marker='o', linestyle='')
plt.plot(t5,e5,marker='o', linestyle='')
plt.plot(t6,e6,marker='o', linestyle='')
plt.plot(t7,e7, marker='o', linestyle='')
plt.show()

plt.plot(t1,a1,marker='o', linestyle='')
plt.plot(t2,a2,marker='o', linestyle='')
plt.plot(t3,a3,marker='o', linestyle='')
plt.plot(t4,a4,marker='o', linestyle='')
plt.plot(t5,a5,marker='o', linestyle='')
plt.plot(t6,a6,marker='o', linestyle='')
plt.plot(t7,a7, marker='o', linestyle='')
plt.show()

# plt.xlim(0, 1000)
# ax1.set_ylabel('Semi-eixo (UA)')

    # ax2.plot(t1,e1,e2, marker='.', linestyle='')
    # ax2.set_xlim(0, 1000)
    # ax2.set_ylabel('Excentricidade')

    # ax3.plot(t1,i1,i2, marker='.', linestyle='')
    # ax3.set_xlim(0, 1000)
    # ax3.set_ylabel('Inclinação (graus)')

    # ax4.plot(t1,w1,w2, marker='.', linestyle='')
    # ax4.set_xlim(0, 1000)
    # ax4.set_ylabel('w (graus)')

    # ax5.plot(t1,nodo1,nodo2, marker='.', linestyle='')
    # ax5.set_xlim(0, 1000)
    # ax5.set_ylabel('Nodo (graus)')
    # ax5.set_xlabel('Tempo (anos)')

plt.show()
# fig.savefig('compare/earth_t1{}.png'.format(trappist[l]))
